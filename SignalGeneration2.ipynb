# %%
from ipywidgets import interact
import ipywidgets as widgets
import time
import warnings
import pandas as pd
warnings.filterwarnings("ignore", category=FutureWarning)
import numpy as np
import plotly.graph_objects as go

# %%
ngrid=1500
idftmatdict={}
N=[20,80]
for n in N:
    nmodes=n+1
    idftmat=np.zeros((ngrid,nmodes),dtype=complex)
    x=np.linspace(-np.pi,np.pi,ngrid)
    nn=np.linspace(-nmodes/2,nmodes/2,nmodes+1)
    print(n)
    print(x)
    for i in range(ngrid):
        for j in range(nmodes):
            idftmat[i][j]=np.e**(1j*x[i]*nn[j])
    
    idftmatdict[n]=idftmat
# Out:
# 20
# [-3.14159265 -3.13740107 -3.13320948 ...  3.13320948  3.13740107
#   3.14159265]
# 80
# [-3.14159265 -3.13740107 -3.13320948 ...  3.13320948  3.13740107
#   3.14159265]

# %%
np.seterr(divide='ignore', invalid='ignore')

def plot(fig,x,y,name):
    fig.add_trace(go.Scatter(x=x,y=y,mode='lines',name=name))
SignalsDict={'Box':1,'Saw':2,'Exp':3,'Sin':4,'Gaus':5}
def Generate(signal,x,Amount,normalized=True,fourier=False,N=40,M=40,Noise=False,noiseParameter=0.1):
    signalOutput=[]
    length=Amount+2
    print(SignalsDict[signal])
    if(SignalsDict[signal]==1):
        #a=np.linspace(np.pi/4,np.pi/2,len(x))
        a=np.linspace(.10,2.90,length)
        b=np.append(np.linspace(-100,-0.01,int(length/2)),np.linspace(0.01,100,int(length/2)))
        a=np.random.permutation(a)
        b=np.random.permutation(b)
        if fourier:
            for i in range(Amount):
                cn=box(x,a[i],b[i],normalized=normalized,fourier=True,N=N)
                normalization=1#np.max(abs(F))
                #BoxSignal.append(F/normalization)
                #BoxSignalFourier.append(fx)
                signalOutput.append(FourierSeries(cn,x,N,M))
            return [signalOutput,a[0:Amount],b[0:Amount]]
        elif Noise:
            for i in range(Amount):
                F=box(x,a[i],b[i],noise=True,normalized=normalized,noiseParameter=noiseParameter)
                signalOutput.append(F)
            return [signalOutput,a[0:Amount],b[0:Amount]]
        else:
            for i in range(Amount):
                F=box(x,a[i],b[i],normalized=normalized)
                #normalization=1#np.max(abs(F))
                #BoxSignal.append(F/normalization)
                #BoxSignalFourier.append(fx)
                signalOutput.append(F)
            return [signalOutput,a[0:Amount],b[0:Amount]]
    elif(SignalsDict[signal]==2):
        a=np.linspace(np.pi/4,np.pi/2,length)
        b=np.append(np.linspace(-100,-0.01,int(length/2)),np.linspace(0.01,100,int(length/2)))
        a=np.random.permutation(a)
        b=np.random.permutation(b)
        if fourier:
            for i in range(Amount):
                cn=saw(x,a[i],b[i],normalized=normalized
                ,fourier=True,N=N)
                signalOutput.append(FourierSeries(cn,x,N,M))
            return [signalOutput,a[0:Amount],b[0:Amount]]
        elif Noise:
            for i in range(Amount):
                F=saw(x,a[i],b[i],noise=True,normalized=normalized,noiseParameter=noiseParameter)
                signalOutput.append(F)
            return [signalOutput,a[0:Amount],b[0:Amount]]
        else:
            for i in range(Amount):
                F=saw(x,a[i],b[i],normalized=normalized)
                signalOutput.append(F)
            return [signalOutput,a[0:Amount],b[0:Amount]]
    elif(SignalsDict[signal]==3):
        a=np.linspace(np.pi/4,np.pi/2,length)
        b=np.append(np.linspace(-1,-0.1,int(length/2)),np.linspace(0.1,1,int(length/2)))
        c=np.append(np.linspace(-3,-1.01,int(length/2)),np.linspace(-1.01,1,int(length/2)))
        a=np.random.permutation(a)
        b=np.random.permutation(b)
        c=np.random.permutation(c)
        if fourier:
            for i in range(Amount):
                cn=exp(x,a[i],b[i],c[i],normalized=normalized
                ,fourier=True,N=N)
                signalOutput.append(FourierSeries(cn,x,N,M))
            return [signalOutput,a[0:Amount],b[0:Amount],c[0:Amount]]
        elif Noise:
            for i in range(Amount):
                F=exp(x,a[i],b[i],c[i],noise=True,normalized=normalized,noiseParameter=noiseParameter)
                signalOutput.append(F)
            return [signalOutput,a[0:Amount],b[0:Amount],c[0:Amount]]
        else:
            for i in range(Amount):
                F=exp(x,a[i],b[i],c[i],normalized=normalized)
                signalOutput.append(F)
            return [signalOutput,a[0:Amount],b[0:Amount],c[0:Amount]]
    elif(SignalsDict[signal]==4):
        a=np.linspace(np.pi/4,np.pi/2,length)
        b=np.append(np.linspace(-2*np.pi,-0.3,int(length/2)),np.linspace(0.3,2*np.pi,int(length/2)))
        c=np.append(np.linspace(-100,-0.1,int(length/2)),np.linspace(0.1,100,int(length/2)))
        a=np.random.permutation(a)
        b=np.random.permutation(b)
        c=np.random.permutation(c)
        if fourier:
            for i in range(Amount):
                cn=sinu(x,a[i],b[i],c[i],normalized=normalized
                ,fourier=True,N=N)
                signalOutput.append(FourierSeries(cn,x,N,M))
            return [signalOutput,a[0:Amount],b[0:Amount],c[0:Amount]]
        elif Noise:
            for i in range(Amount):
                F=sinu(x,a[i],b[i],c[i],noise=True,normalized=normalized,noiseParameter=noiseParameter)
                signalOutput.append(F)
            return [signalOutput,a[0:Amount],b[0:Amount],c[0:Amount]]
        else:
            for i in range(Amount):
                F=sinu(x,a[i],b[i],c[i],normalized=normalized)
                signalOutput.append(F)
            return [signalOutput,a[0:Amount],b[0:Amount],c[0:Amount]]
    elif(SignalsDict[signal]==5):
        a=np.linspace(np.pi/4,np.pi/2,length)
        #b=np.append(np.linspace(-10,-1,int(length/2)),np.linspace(1,10,int(length/2)))
        b=np.linspace(1,10,length)
        a=np.random.permutation(a)
        b=np.random.permutation(b)

        if fourier:
            for i in range(Amount):
                #x=np.linspace(-np.pi,np.pi,N)
                cn=gaus(x,a[i],int(b[i]),fourier=True,N=N,M=M)
                fx=FourierSeries(cn,x,M)
                #cn=gaus(x,a[i],int(b[i]),normalized=normalized,fourier=True,N=N,M=M)
                signalOutput.append(fx)
            return [signalOutput,a[0:Amount],b[0:Amount]]
        elif Noise:
            for i in range(Amount):
                F=gaus(x,a[i],int(b[i]),noise=True,normalized=normalized,noiseParameter=noiseParameter)
                signalOutput.append(F)
            return [signalOutput,a[0:Amount],b[0:Amount]]
        else:
            for i in range(Amount):
                F=gaus(x,a[i],int(b[i]),normalized=normalized)
                signalOutput.append(F)
            return [signalOutput,a[0:Amount],b[0:Amount]]
def FourierSeries2(cn,X,N,M=0):
    fx=[]
    #X=np.linspace(-np.pi,np.pi,M)
     
    result=0
    for x in X:
        result=0
        for i in range(int((-N/2)),int((N/2))):
            result=result+cn[int(i+(N/2))]*(np.e**(1j*i*x)) #Calculate Fourier Series approximation using formula
        fx.append(result.real)
    return fx
def FourierSeries3(cn,X,N,M=0):
    fx=[]
    #X=np.linspace(-np.pi,np.pi,M)
    return np.dot(idftmatdict[N],cn).real

# %%
def dft(N,M=40):
    #w=np.e**((2*np.pi*-1j)/N)
    power=np.zeros((M,N),dtype=complex)
    xj = np.linspace(-np.pi, np.pi, N)
    for i in range(M):
        for j in range(N):
            #power[i][j]=((-N/2)+i)*j
            power[i][j] = -1j*(i-M/2)*xj[j]
    #DFT=(w**power)/N
    DFT = np.e**power
    return DFT
def box(x,a=2,b=5,normalized=True,jump=False,noise=False,noiseParameter=0.1,fourier=False,N=40):
    if fourier:
        k=np.linspace(int((-N/2)),int((N/2)),N+1)
        print(k)
        fkhat=np.zeros(len(k))
        fkhat[k==0]=(2*a*b)
        fkhat[k!=0]=((2*b*np.sin(a*k[k!=0]))/k[k!=0])
        y=fkhat/(2*np.pi)
        if normalized:
            return y/np.max(abs(box(x,a,b,normalized=False)))
        return y
    y=np.zeros(len(x))
    y[np.abs(x)<a]=b
    if noise:
        y=y+np.random.normal(0,noiseParameter,len(x))
        if normalized:
            return y/np.max(abs(box(x,a,b,normalized=False)))
        return y
    if normalized:
        if jump:
            y=y/np.max(abs(y))
            fk=np.zeros(len(x))
            print(fk)
            print(a)
            '''
            x=x.round(decimals=1)
            fk[x==a]=y[x==a]
            fk[x==-a]=y[x==-a]
            '''
            fk[np.abs(x-a)<0.01]=y[np.abs(x-a)<0.01]
            fk[np.abs(x+a)<0.01]=y[np.abs(x+a)<0.01]
            print(fk)
            return y,fk
        return y/np.max(abs(y))
    return y
def saw(x,a=2,b=5,normalized=True,jump=False,noise=False,noiseParameter=0.1,fourier=False,N=40):
    if fourier:
        k=np.linspace(int((-N/2)),int((N/2)),N+1)
        fkhat=np.zeros(len(k)).astype(complex)
        fkhat[k==0]=0
        fkhat[k!=0]=(2*1j*b*(np.sin(a*k[k!=0])-a*k[k!=0]*np.cos(a*k[k!=0])))/(k[k!=0]**2)
        y=fkhat/(2*np.pi)
        if normalized:
            return y/np.max(abs(saw(x,a,b,normalized=False)))
        return y
    y=np.zeros(len(x))
    y[np.abs(x)<a]=-b*x[np.abs(x)<a]
    if noise:
        y=y+np.random.normal(0,noiseParameter,len(x))
        if normalized:
            return y/np.max(abs(saw(x,a,b,normalized=False)))
        return y
    if normalized:
        if jump:
            y=y/np.max(abs(y))
            fk=np.zeros(len(x))
            print(fk)
            print(a)
            '''
            x=x.round(decimals=1)
            fk[x==a]=y[x==a]
            fk[x==-a]=y[x==-a]
            '''
            fk[np.abs(x-a)<0.01]=y[np.abs(x-a)<0.01]
            fk[np.abs(x+a)<0.01]=y[np.abs(x+a)<0.01]
            print(fk)
            return y,fk
        return y/np.max(abs(y))
    return y
def exp(x,a=2,b=2,c=-1,normalized=True,jump=False,noise=False,noiseParameter=0.1,fourier=False,N=40):
    if fourier:
        k=np.linspace(int((-N/2)),int((N/2)),N+1).astype(complex)
        fkhat=np.zeros(len(k)).astype(complex)
        fkhat[k==0]=(2*((a*b*c)+np.sinh(a*b)))/b
        fkhat[k!=0]=((2*c*np.sin(a*k[k!=0]))/k[k!=0])+((2*np.sinh(a*(b+(1j*k[k!=0]))))/(b+(1j*k[k!=0])))
        y=fkhat/(2*np.pi)
        if normalized:
            return y/np.max(abs(exp(x,a,b,c,normalized=False)))
        return y
    y=np.zeros(len(x))
    y[np.abs(x)<a]=c+np.e**(-b*x[[np.abs(x)<a]])
    if noise:
        y=y+np.random.normal(0,noiseParameter,len(x))
        if normalized:
           return y/np.max(abs(exp(x,a,b,c,normalized=False)))
        return y
    if normalized:
        if jump:
            y=y/np.max(abs(y))
            fk=np.zeros(len(x))
            print(fk)
            print(a)
            '''
            x=x.round(decimals=1)
            fk[x==a]=y[x==a]
            fk[x==-a]=y[x==-a]
            '''
            fk[np.abs(x-a)<0.01]=y[np.abs(x-a)<0.01]
            fk[np.abs(x+a)<0.01]=y[np.abs(x+a)<0.01]
            print(fk)
            return y,fk
        return y/np.max(abs(y))
    return y
def sinu(x,a=2,b=2,c=-1,normalized=True,jump=False,noise=False,noiseParameter=0.1,fourier=False,N=40):
    if fourier:
        k=np.linspace(int((-N/2)),int((N/2)),N+1).astype(complex)
        fkhat=np.zeros(len(k)).astype(complex)
        fkhat[k==b]=((1j*c*np.sin(2*a*b))/(2*b))-(1j*a*c)
        fkhat[k==-b]=(1/2)*1j*c*((2*a)-((np.sin(2*a*b))/b))
        fkhat[k!=b]=(2*1j*c*((b*np.cos(a*b)*np.sin(a*k[k!=b]))-(k[k!=b]*np.sin(a*b)*np.cos(a*k[k!=b]))))/((b**2)-(k[k!=b]**2))
        y=fkhat/(2*np.pi)
        if normalized:
            return y/np.max(abs(sinu(x,a,b,c,normalized=False)))
        return y
    y=np.zeros(len(x))
    y[np.abs(x)<a]=c*np.sin(b*x[np.abs(x[0:1500])<a])
    if noise:
        y=y+np.random.normal(0,noiseParameter,len(x))
        if normalized:
            return y/np.max(abs(sinu(x,a,b,c,normalized=False)))
        return y
    if normalized:
        if jump:
            y=y/np.max(abs(y))
            fk=np.zeros(len(x))
            print(fk)
            print(a)
            '''
            x=x.round(decimals=1)
            fk[x==a]=y[x==a]
            fk[x==-a]=y[x==-a]
            '''
            fk[np.abs(x-a)<0.01]=y[np.abs(x-a)<0.01]
            fk[np.abs(x+a)<0.01]=y[np.abs(x+a)<0.01]
            print(fk)
            return y,fk
        return y/np.max(abs(y))
    return y
def gaus(x,a=2,b=2,normalized=True,jump=False,noise=False,noiseParameter=0.1,fourier=False,N=40,M=40):
    if fourier:
        fkhat=((np.dot(dft(N,M),gaus(x,a,b)))/N)
        if normalized:
            return fkhat/np.max(abs(gaus(x,a,b,normalized=False)))
        return fkhat
    y=np.zeros(len(x))
    y[np.abs(x)<a]=np.e**(-a*(x[np.abs(x)<a]**(2*b)))
    y=np.nan_to_num(y)
    if noise:
        y=y+np.random.normal(0,noiseParameter,len(x))
        if normalized:
            return y/np.max(abs(gaus(x,a,b,normalized=False)))
        return y
    if normalized:
        if jump:
            y=y/np.max(abs(y))
            fk=np.zeros(len(x))
            print(fk)
            print(a)
            '''
            x=x.round(decimals=1)
            fk[x==a]=y[x==a]
            fk[x==-a]=y[x==-a]
            '''
            fk[np.abs(x-a)<0.01]=y[np.abs(x-a)<0.01]
            fk[np.abs(x+a)<0.01]=y[np.abs(x+a)<0.01]
            print(fk)
            return y,fk
        return y/np.max(abs(y))
    return y
from scipy.fft import fft, ifft,ifftshift
def FourierSeries(cn,X,N,M=0,y=0):
   # print(len(cn))
    #print(N)
    fx=[]
    print(cn)
    #X=np.linspace(-np.pi,np.pi,M)
    i=np.linspace(1,100,100)
    Cn=np.zeros(len(X))
    print(Cn)
    Cn[0]=cn[int(N/2)]
    print(Cn)
    print(int(N/2))
    Cn[1:int(N/2)+1]=cn[int(N/2)+1:N+1]
    print(Cn)
    Cn[len(X)-int(N/2):len(X)]=cn[0:int(N/2)]
    print(Cn)
    fx=len(X)*ifftshift(ifft(Cn))
    #fx=len(X)*(ifft(Cn))
    #temp=(np.e**(1j*(i*x)))
    #print((fx*temp).real)

    return fx.real

# %%
x=np.linspace(-np.pi,np.pi,1500)

# %%
def et(x,n,sign=1):
    if sign==1:
        return np.e**(1j*x*n)
    else:
        return np.e**(-1j*x*n)

def trigSig(n):

        Sipi=1.85193705198247
        sig=np.pi*np.sin((np.pi*np.abs(n))/(np.max(n)))/Sipi
        return sig
def polySig(n):
    sig=(np.pi*np.abs(n)/np.max(n))
    return sig
def expSig(n):
    alpha=2
    tau=np.linspace(1/np.max(N),1-(1/np.max(N)),1000)
    res=tau[1]-tau[0]
    const = np.pi/( res*sum(np.e**(1/(alpha*tau*(tau-1)))) )
    sig = const*( np.abs(n)/np.max(n) )*np.e**(1/(alpha*(np.abs(n)/max(n))*((np.abs(n)/max(n))-1)));
    sig[n==0]=0
    sig[0]=0
    sig[-1]=0
    return sig

'''
    type determines which fourier coefficient to calculate
        trig:1
        exp:2
        poly:3
'''
def partialFourierSum(M2,M1,x,n,cn,type=1):
    D2=np.zeros((M2-1,M1),dtype=complex)
    for p in range(M2-1):
      for q in range(M1-1):
        D2[p][q]=(et(x[p],n[q]))
    if type==1:
        sig=trigSig(n)
    elif type==2:
        sig=polySig(n)
    elif type==3:
        sig=expSig(n)
    SN=cn*(1j*np.sign(n)*sig)
    fx = np.dot(D2,SN)
    return fx.real
cn=exp(x,3,-2,-100,normalized=True,fourier=True,N=100)
N=[100]
M1=len(cn)
M2=1500
n=np.linspace(-M1/2,M1/2,M1)
h=np.linspace(0,M2-1,M2-1)
X =-np.pi+ (2*np.pi/M2)*h
#x=np.linspace(-5,5,M2-1)
fig=go.Figure()
plot(fig,x,partialFourierSum(M2,M1,x,n,cn,1),'Trig')
plot(fig,x,partialFourierSum(M2,M1,x,n,cn,2),'Poly')
plot(fig,x,partialFourierSum(M2,M1,x,n,cn,3),'Exp')
fig.show()

# %% [markdown]
# # Visualization of signals

# %%
N=1500
xx=np.linspace(-np.pi,np.pi,N+1)
print(xx)
x=xx[0:-1]
print(x)
fig=go.Figure()
fig.add_trace(go.Scatter(x=x,y=box(x,0.1,0.1,normalized=False),mode='lines',name='Box'))
fig.update_xaxes(range=[-np.pi,np.pi])
fig.update_yaxes(range=[-0.4,1.2])


k=np.linspace(0,N,N)
#print(fx)
a=0
b=0


@interact(a=(0.1,3.1,0.1),b=(-100, 100, 0.1))
def update(FourierRepresentation=False,JumpTrig=False,JumpPoly=False,JumpExp=False,a=0.1,b=0.1):
    with fig.batch_update():
        fig.data[0].y=box(x,a,b,jump=True,normalized=True)[1]
        if(FourierRepresentation):
            if(len(fig.data)==1):
                #cn=BoxFourierAnalytical(a,b,N)
                

                #fx2=FourierSeries2(cn,x,20)
                #fx3=FourierSeries3(cn,x,20)
                #print(fx3)
                cn=box(x,a,b,normalized=True,fourier=True,N=20)
                fx20=FourierSeries2(cn,x,20)
                cn=box(x,a,b,normalized=True,fourier=True,N=80)
                fx80=FourierSeries2(cn,x,80)
                fig.add_trace(go.Scatter(
            x=x,y=fx20,mode="lines",line = dict(color='red', width=2, dash='dash'),name='Fourier Representation N=20'
        ))
                fig.add_trace(go.Scatter(
            x=x,y=fx80,mode="lines",line = dict(color='green', width=2, dash='dash'),name='Fourier Representation N=80'
        ))
        #         fig.add_trace(go.Scatter(
        #     x=x,y=fx2,mode="lines",line = dict(color='blue', width=2, dash='dash'),name='double for loop Fourier Representation N=50'
        # ))
        #         fig.add_trace(go.Scatter(x=x,y=fx3,mode="lines",line = dict(color='green', width=2, dash='dash'),name='matrix-vec Fourier Representation N=50'
        # ))                #plot(fig,x,fx,'FourierRepresentation')

            else:
                cn=box(x,a,b,fourier=True,N=150)
                fx=FourierSeries(cn,x,150)
                fig.data[1].y=fx
        else:
            fig.data = [fig.data[0]]
        fig.update_layout(legend=dict(x=0.75,y=0))
        layout = {

            'xaxis': { 

               # 'range': [0.2, 1],
                'zeroline': True,
                'showgrid': True,
                'zeroline':False,
                'zerolinecolor' : 'grey',
                'title_text':r'$x$',
                'dtick':0.5
                },
            'yaxis': {
                   # 'range': [0, 1],
                    'showgrid': True,
                    'zeroline':False,
                'zerolinecolor' : 'grey',
                    'dtick':0.1,
                    'title_text':r'$f(x)$'
                },
            'title':{
                'text':'The Box Function',
                'x':0.5,
                
                
            }

            }
        fig.update_layout(layout)
        fig.update_layout(height=840,width=1120)

        fig.show()

# %% [markdown]
# ## 2. Sawtooth

# %%
N=1500
xx=np.linspace(-np.pi,np.pi,N+1)
print(xx)
x=xx[0:-1]
print(x)
fig=go.Figure()
fig.add_trace(go.Scatter(x=x,y=saw(x,0.1,0.1,normalized=False),mode='lines',name='Saw'))
fig.update_xaxes(range=[-np.pi,np.pi])
fig.update_yaxes(range=[-1.2,1.2])


k=np.linspace(0,N,N)
#print(fx)
a=0
b=0

k=np.linspace(0,N,N)
#print(fx)
a=0
b=0


@interact(a=(0.1,3.1,0.1),b=(-1, 1, 0.1))
def update(FourierRepresentation=False,a=0.1,b=0.1):
    with fig.batch_update():
        fig.data[0].y=saw(x,a,b,jump=True,normalized=True)[1]
        if(FourierRepresentation):
            if(len(fig.data)==1):
                #cn=BoxFourierAnalytical(a,b,N)
                
                
                
                cn=saw(x,a,b,fourier=True,N=20)
                fx20=FourierSeries2(cn,x,20)
                cn=saw(x,a,b,fourier=True,N=80)
                fx80=FourierSeries2(cn,x,80)
                fig.add_trace(go.Scatter(
            x=x,y=fx20,mode="lines",line = dict(color='red', width=2, dash='dash'),name='Fourier Representation N=20'
        ))
                fig.add_trace(go.Scatter(
            x=x,y=fx80,mode="lines",line = dict(color='green', width=2, dash='dash'),name='Fourier Representation N=80'
        ))
                
            
            else:
                cn=saw(x,a,b,fourier=True,N=50)
                fx=FourierSeries(cn,x,50)
                fig.data[1].y=fx
        else:
            fig.data = [fig.data[0]]
        fig.update_layout(legend=dict(x=0.75,y=0))
        layout = {

            'xaxis': { 

               # 'range': [0.2, 1],
                'zeroline': True,
                'showgrid': True,
                'zeroline':False,
                'zerolinecolor' : 'grey',
                'title_text':r'$x$',
                'dtick':0.5
                },
            'yaxis': {
                   # 'range': [0, 1],
                    'showgrid': True,
                    'zeroline':False,
                'zerolinecolor' : 'grey',
                    'dtick':0.1,
                    'title_text':r'$f(x)$'
                },
            'title':{
                'text':'The Saw Function',
                'x':0.5,
                
                
            }

            }
        fig.update_layout(layout)
        fig.update_layout(height=840,width=1120)
        fig.show()

# %% [markdown]
# ## 3. Exponential

# %%
N=1500
xx=np.linspace(-np.pi,np.pi,N+1)
print(xx)
x=xx[0:-1]
print(x)
fig=go.Figure()
fig.add_trace(go.Scatter(x=x,y=exp(x,0,0),mode='lines',name='Exp'))
fig.update_xaxes(range=[-np.pi,np.pi])
fig.update_yaxes(range=[-0.4,1.2])
@interact(a=(0.1,3,0.1),b=(-1.1, 1.1, 0.1),c=(-3,1,0.1))
def update(FourierRepresentation=False,a=0.1,b=0.1,c=0):
    with fig.batch_update():
        fig.data[0].y=exp(x,a,b,c,jump=True)[1]
        if(FourierRepresentation):
            if(len(fig.data)==1):
                cn=exp(x,a,b,c,fourier=True,N=20)
                fx20=FourierSeries2(cn,x,20)
                cn=exp(x,a,b,c,fourier=True,N=80)
                fx80=FourierSeries2(cn,x,80)
                fig.add_trace(go.Scatter(
            x=x,y=fx20,mode="lines",line = dict(color='red', width=2, dash='dash'),name='Fourier Representation N=20'
        ))
                fig.add_trace(go.Scatter(
            x=x,y=fx80,mode="lines",line = dict(color='green', width=2, dash='dash'),name='Fourier Representation N=80'
        ))
            else:
                #cn=ExpFourierAnalytical(a,b,c,N)
                #cn=((np.dot(fft(N,M),exp(x,a,b,c)))/N)
                cn=exp(x,a,b,c,fourier=True,N=100)
                fx=FourierSeries(cn,x,N)
                fig.data[1].y=fx
        else:
            fig.data = [fig.data[0]]
        fig.update_layout(legend=dict(x=0.75,y=0))

        layout = {

            'xaxis': { 

               # 'range': [0.2, 1],
                'zeroline': True,
                'showgrid': True,
                'zeroline':False,
                'zerolinecolor' : 'grey',
                'title_text':r'$x$',
                'dtick':0.5
                },
            'yaxis': {
                   # 'range': [0, 1],
                    'showgrid': True,
                    'zeroline':False,
                'zerolinecolor' : 'grey',
                    'dtick':0.1,
                    'title_text':r'$f(x)$'
                },
            'title':{
                'text':'The Exponential Function',
                'x':0.5,
                
                
            }

            }
        fig.update_layout(layout)
        fig.update_layout(height=840,width=1120)

        fig.show()

# %% [markdown]
# ## 4.Sinusoid

# %%
N=1500
xx=np.linspace(-np.pi,np.pi,N+1)
print(xx)
x=xx[0:-1]
print(x)
fig=go.Figure()
fig.add_trace(go.Scatter(x=x,y=sinu(x,0,0,0),mode='lines',name='Sin'))
fig.update_xaxes(range=[-np.pi,np.pi])
fig.update_yaxes(range=[-1.3,1.2])

@interact(a=(0.1,3,0.1),b=(-1.1, 1.1, 0.1),c=(-3,1,0.1))
def update(FourierRepresentation=False,a=0.1,b=0.1,c=0):
    with fig.batch_update():
        fig.data[0].y=sinu(x,a,b,c,jump=True)[1]
        if(FourierRepresentation):
            if(len(fig.data)==1):
                #cn=SinuFourierAnalytical(a,b,c,N)
                cn=sinu(x,a,b,c,fourier=True,N=20)
                fx20=FourierSeries2(cn,x,20)
                cn=sinu(x,a,b,c,fourier=True,N=80)
                fx80=FourierSeries2(cn,x,80)
                fig.add_trace(go.Scatter(
            x=x,y=fx20,mode="lines",line = dict(color='red', width=2, dash='dash'),name='Fourier Representation N=20'
        ))
                fig.add_trace(go.Scatter(
            x=x,y=fx80,mode="lines",line = dict(color='green', width=2, dash='dash'),name='Fourier Representation N=80'
        ))
            else:
                #cn=SinuFourierAnalytical(a,b,c,N)
                cn=sinu(x,a,b,c,fourier=True,N=100)
                fx=FourierSeries(cn,x,N)
                fig.data[1].y=fx
        else:
            fig.data = [fig.data[0]]
        fig.update_layout(legend=dict(x=0.75,y=0))

        layout = {

            'xaxis': {

               # 'range': [0.2, 1],
                'zeroline': True,
                'showgrid': True,
                'zeroline':False,
                'zerolinecolor' : 'grey',
                'title_text':r'$x$',
                'dtick':0.5
                },
            'yaxis': {
                   # 'range': [0, 1],
                    'showgrid': True,
                    'zeroline':False,
                'zerolinecolor' : 'grey',
                    'dtick':0.1,
                    'title_text':r'$f(x)$'
                    #'title_text':r'$(x)$'
                
                },
            'title':{
                'text':'The Sinusoidal Function',
                'x':0.5,


            }

            }
        fig.update_layout(layout)
        fig.update_layout(height=840,width=1120)
        fig.show()

# %% [markdown]
# ## 5. Gaussian

# %%
N=1500
xx=np.linspace(-np.pi,np.pi,N+1)
print(xx)
x=xx[0:-1]
print(x)
fig=go.Figure()
fig.add_trace(go.Scatter(x=x,y=gaus(x,0,0),mode='lines',name='Gaus'))
fig.update_xaxes(range=[-np.pi,np.pi])
fig.update_yaxes(range=[-0.2,1.2])
@interact(a=(0.1,5,0.1),b=(-1.1, 10, 0.1))
def update(FourierRepresentation=False,a=0.1,b=0.1):
    with fig.batch_update():
        fig.data[0].y=gaus(x,a,b,jump=True)[1]
        if(FourierRepresentation):
            if(len(fig.data)==1):
                #cn=((np.dot(fft(N,M),gaus(x,a,b)))/N)
                
                cn=gaus(x,a,b,fourier=True,N=N,M=20)
                fx20=FourierSeries2(cn,x,20)
                cn=gaus(x,a,b,fourier=True,N=N,M=80)
                fx80=FourierSeries2(cn,x,80)
                fig.add_trace(go.Scatter(
            x=x,y=fx20,mode="lines",line = dict(color='red', width=2, dash='dash'),name='Fourier Representation N=20'
        ))
                fig.add_trace(go.Scatter(
            x=x,y=fx80,mode="lines",line = dict(color='green', width=2, dash='dash'),name='Fourier Representation N=80'
        ))

            else:
                #cn=(np.dot(fft(N,80),gaus(x,a,b))/N)
                cn=gaus(x,a,b,fourier=True,N=N,M=M)
                fx=FourierSeries(cn,x,M)
                fig.data[1].y=fx
                
        else:
            fig.data = [fig.data[0]]
        fig.update_layout(legend=dict(x=0.75,y=0))

        layout = {

            'xaxis': {

               # 'range': [0.2, 1],
                'zeroline': True,
                'showgrid': True,
                'zeroline':False,
                'zerolinecolor' : 'grey',
                'title_text':r'$x$',
                'dtick':0.5
                },
            'yaxis': {
                   # 'range': [0, 1],
                    'showgrid': True,
                    'zeroline':False,
                'zerolinecolor' : 'grey',
                    'dtick':0.1,
                    'title_text':r'$f(x)$'
                    #'title_text':r'$(x)$'
                
                },
            'title':{
                'text':'The Gaussian Function',
                'x':0.5,


            }

            }
        fig.update_layout(layout)
        fig.update_layout(height=840,width=1120)
        fig.show()
