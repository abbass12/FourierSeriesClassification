# %% [markdown]
# ## Step Function

# %% [markdown]
# ### Fourier Series Approximation

# %%
import plotly.graph_objects as go
import numpy as np
import pandas as pd

fourier=pd.DataFrame() # To collect data

x = np.linspace(0,2*np.pi,400) #Genearate 400 points between 0 and 2pi

a=np.empty(int(len(x)/2))
a.fill(1)
b=np.empty(int(len(x)/2)) # Step Function Declaration, first half will be equal to one, and second half will be equal to -1
b.fill(-1)
CC=np.append(a,b) #joins two halves


fourier['x']=x
fourier['actualData']=CC


nval=[20, 40, 80, 160, 500, 1000]#Different values of n for coefficients
for n in nval:
    L=np.pi
    a0=0 
    an=0  # Based on calculation, an and a0 is equal to 0
    bn=[]
    fx=[]
    for i in range(1,n+1):
        b=(1/(i*np.pi))*(2*(1-np.cos(i*np.pi))) #Generate bn coefficients based on formula
        #b = b*(1*i*(np.pi/(n/2)))
        bn.append(b)
    for a in x:
        result=0
        for i in range(1,n+1):
            result=result+(bn[i-1])*np.sin(i*a) #Calculate Fourier Series approximation using formula
        fx.append(result/1)# For some reason, I had to divide by 10 because that was where the fourier series was converging to, not sure why exactly.
    fourier['n=%s'%(n)]=fx #Add to data frame based on the value of n

# %%
fourier #result
# Out:
#             x  actualData  ...         n=500        n=1000
# 0    0.000000         1.0  ...  0.000000e+00  0.000000e+00
# 1    0.015747         1.0  ...  5.180433e-01  5.078468e-01
# 2    0.031495         1.0  ...  5.079097e-01  3.935450e-04
# 3    0.047242         1.0  ...  1.594060e-01  1.688138e-01
# 4    0.062989         1.0  ...  3.937403e-04  7.862607e-04
# ..        ...         ...  ...           ...           ...
# 395  6.220196        -1.0  ... -3.937403e-04 -7.862607e-04
# 396  6.235943        -1.0  ... -1.594060e-01 -1.688138e-01
# 397  6.251691        -1.0  ... -5.079097e-01 -3.935450e-04
# 398  6.267438        -1.0  ... -5.180433e-01 -5.078468e-01
# 399  6.283185        -1.0  ... -2.464073e-13 -4.871871e-13
#
# [400 rows x 8 columns]

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(x=fourier['x'],y=fourier['actualData'],mode='lines',name='+1-1Function'))
fig.add_trace(go.Scatter(x=fourier['x'],y=fourier['n=20'],mode='lines',name='n=20'))
fig.add_trace(go.Scatter(x=fourier['x'],y=fourier['n=40'],mode='lines',name='n=40'))
fig.add_trace(go.Scatter(x=fourier['x'],y=fourier['n=80'],mode='lines',name='n=80'))
fig.add_trace(go.Scatter(x=fourier['x'],y=fourier['n=160'],mode='lines',name='n=160'))
fig.add_trace(go.Scatter(x=fourier['x'],y=fourier['n=500'],mode='lines',name='n=500'))
fig.add_trace(go.Scatter(x=fourier['x'],y=fourier['n=1000'],mode='lines',name='n=1000'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8e5a92c5-2b8d-4674-8594-c53b960064cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e5a92c5-2b8d-4674-8594-c53b960064cf")) {                    Plotly.newPlot(                        "8e5a92c5-2b8d-4674-8594-c53b960064cf",                        [{"mode":"lines","name":"+1-1Function","x":[0.0,0.01574733159694132,0.03149466319388264,0.04724199479082396,0.06298932638776528,0.0787366579847066,0.09448398958164791,0.11023132117858923,0.12597865277553055,0.14172598437247186,0.1574733159694132,0.17322064756635452,0.18896797916329583,0.20471531076023713,0.22046264235717847,0.2362099739541198,0.2519573055510611,0.2677046371480024,0.2834519687449437,0.2991993003418851,0.3149466319388264,0.3306939635357677,0.34644129513270905,0.36218862672965035,0.37793595832659166,0.39368328992353296,0.40943062152047427,0.42517795311741563,0.44092528471435694,0.45667261631129824,0.4724199479082396,0.4881672795051809,0.5039146111021222,0.5196619426990635,0.5354092742960048,0.5511566058929461,0.5669039374898874,0.5826512690868288,0.5983986006837702,0.6141459322807115,0.6298932638776528,0.6456405954745941,0.6613879270715354,0.6771352